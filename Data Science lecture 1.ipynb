# %%
if 5 > 2:
    print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
print("hello world") #this is a comment
# Out:
# hello world

# %%
x = 5
y = "Joy"
print(x)
print(y)

# %%
x = 5 #This is a type of integer 
y = "Joy" #This is a type of STRING
print(x)
print(y)
# Out:
# 5
# Joy

# %%
x = int(5)
y = str("Joy")
z = float(3.0)
print(x)
print(y)
print(z)
# Out:
# 5
# Joy
# 3.0

# %%
myVar = "John" #Variables can be named--case sensitive and can't start with a number
print(myVar)
# Out:
# John

# %%
x, y, z = "Orange", "Banana", "Grapes"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Grapes

# %%
x = y = z = "Banana" 
print(x)
print(y)
print(z)
# Out:
# Banana
# Banana
# Banana

# %%
x = "python is awesome"
print(x)
# Out:
# python is awesome

# %%
x = "python"
y = "is"
z = "awesome"
print (x, y, z)
# Out:
# python is awesome

# %%
x = "python" 
y = "is" 
z = "awesome"
(x + y + z)
# Out:
# 'pythonisawesome'

# %%
x = "python "
y = "is "
z = "awesome"
(x + y + z)
# Out:
# 'python is awesome'

# %%
x = 5
y = 10 
(x + y)
# Out:
# 15

# %%
x = 5 
y = "Joy" #When adding int and str use commas not +
(x, y)
# Out:
# (5, 'Joy')

# %%
x = "awesome"

def myfunc():
    print("Python is " + x)

# %%
# I can't seem to get the () down

# %%
x = 1 # int
y = 2.8 # flt
z = 2j # complex
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
# int is a whole number no decimels + or -
# flt is a decimal + or - or you can use 'to the power' (e) 2e67.1

# %%
x = int(1) # x will be 1
y = int(2.1) # y will be 2.1
z = int("3") # z will be 3
print(x, y, z)
# Out:
# 1 2 3

# %%
print("it's alright")
# Out:
# it's alright

# %%
b = "hello, world!"
print(b[2:5])
# Out:
# llo

# %%
#printing charcters 2-5 above--first character starts at 0

# %%
a = "Hello, world!"
print(a.upper())
# Out:
# HELLO, WORLD!

# %%
a = "Hello, world!" 
print(a.strip()) #the strip() removes any white space from the beginning or end
# Out:
# Hello, world!

# %%
a = "hello " 
b = "world" 
c = a + b 
print (c)
# Out:
# hello world

# %%
a = "hello" # add a space just add " "
b = "world" 
c = a + " " + b
print(c)
# Out:
# hello world

# %%
age = 36 
txt = f"my name is Tarra, I am {36}" #combine int and text using format()
print(txt)
# Out:
# my name is Tarra, I am 36

# %%
#Booleon values--true or false given more than 1 values

# %%
print(10>4)
print(10==4)
print(10<4)
# Out:
# True
# False
# False

# %%
a = 200
b = 33

if b > a:
    print("b is greater than a")
else:
    print("b is not greater than a")
# Out:
# b is not greater than a

# %%
# the bool() tool tells you when anything is true or false

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
print(60 / 1.58e2)
# Out:
# 0.379746835443038

# %%
1.58e2
# Out:
# 158.0

# %%
60 / 158
# Out:
# 0.379746835443038

# %%
"7" + "3"
# Out:
# '73'

# %%
print(bool("Booleans"))
print(bool("Booleans2"))
print(bool("Strings"))
print(bool("Strings2"))
print(bool("Operators2"))
print(bool("String2"))
# Out:
# True
# True
# True
# True
# True
# True
